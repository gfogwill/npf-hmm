# %%
# %reload_ext autoreload
# %autoreload 2

import logging
logging.basicConfig()
logging.getLogger().setLevel(logging.WARNING)

# %% [markdown]
# ## Series de datos

# %% [markdown]
# Creo las series de datos a usar para entrenar y evaluar los modelos
#
# La serie de datos 'dmps' contiene mediciones cada 10 minutos de la función de densidad de concentración en número de partículas $dn_N(D_p) d log(D_p)$ dados 25 diámetros que están espaciados logarítmicamente entre \SI{10}{\nm} y \SI{800}{\nm}.

# %%
from npfd import data

X_train, X_val, y_train, y_val = data.dataset.make_dataset(dataset_name='dmps', test_size=0.2, seed=27)

print(f"Nº total de archivos: {X_train['count'] + X_val['count']}\n\
Nº de archivos de entrnamiento: {X_train['count']}\n\
Nº de archivos de validación: {X_val['count']}")
# Out:
# Nº total de archivos: 1237
# Nº de archivos de entrnamiento: 979
# Nº de archivos de validación: 258

# %%
with open(y_train['mlf']) as fi:
    tmp = fi.read().replace('\n','').split('.')
    count_ne = 0
    count_e = 0

    for line in tmp:
        if line.startswith('*') or line.startswith("\"") or line.startswith("#"):
            pass
        else:
            if len(line.split()) == 3:
                count_ne += 1
            else:
                count_e += 1

    count_e -= 1
    print(f"""
    ENTRENAMIENTO
    Número de días sin evento: {count_ne} ({count_ne/(count_ne+count_e) * 100})\n\
    Número de días con evento: {count_e}  ({count_e/(count_ne+count_e) * 100})\n\
    Número total de días: {count_ne+count_e}""")
# Out:
#     ENTRENAMIENTO
#     Número de días sin evento: 847 (86.51685393258427)
#     Número de días con evento: 132  (13.48314606741573)
#     Número total de días: 979

# %%
with open(y_val['mlf']) as fi:
    tmp = fi.read().replace('\n','').split('.')
    count_ne = 0
    count_e = 0

    for line in tmp:
        if line.startswith('*') or line.startswith("\"") or line.startswith("#"):
            pass
        else:
            if len(line.split()) == 3:
                count_ne += 1
            else:
                count_e += 1

    count_e -= 1
    print(f"""
    EVALUACION
    Número de días sin evento: {count_ne} ({count_ne/(count_ne+count_e) * 100})\n\
    Número de días con evento: {count_e}  ({count_e/(count_ne+count_e) * 100})\n\
    Número total de días: {count_ne+count_e}""")
# Out:
#     EVALUACION
#     Número de días sin evento: 220 (85.27131782945736)
#     Número de días con evento: 38  (14.728682170542637)
#     Número total de días: 258

# %% [markdown]
# Genero los graficos de los datos a usar con sus etiquetas

# %%
from npfd import visualization as viz

# viz.visualize.generate_plots('train', X_train, y_train)
# viz.visualize.generate_plots('test', X_val, y_val)

# %% [markdown]
# ## HTK

# %%
from npfd.models.base import HiddenMarkovModel

vf = 0.1092
mv = 5.0963637929239754e-5


# Inicializo el modelo
model = HiddenMarkovModel()
model.initialize(X_train, variance_floor=vf, minimum_variance=mv)
model.train(X_train, y_train, minimum_variance=mv)

# Editoel modelo NE y entreno
model.edit([f'AT 2 4 0.2 {{ne.transP}}', 
            f'AT 4 2 0.2 {{ne.transP}}',
            f'AT 2 4 0.2 {{e.transP}}', 
            f'AT 4 2 0.2 {{e.transP}}',
           ])
model.train(X_train, y_train, minimum_variance=mv)

# Aumento el número de gaussianas
gaussian_duplication_times = 4

for i in range(1, gaussian_duplication_times+1):
    model.edit([f'MU {2**i} {{*.state[2-4].mix}}'])
    model.train(X_train, y_train, minimum_variance=mv)
    
    results = model.test(X_val, y_val)
    print(f"mfcc: {results['MMC']}")
# Out:
# /home/gfogwil/Documentos/Facultad/Tesis/models/bdb/notebooks/RPIC
# Pruning-Off
#
# Pruning-Off
#
# Pruning-Off
#
#
# Pruning-Off
#
# Pruning-Off
#
# Pruning-Off
#
#
# Pruning-Off
#
# Pruning-Off
#
# Pruning-Off
#
#
# ====================== HTK Results Analysis =======================
#   Date: Tue Sep 14 20:31:59 2021
#   Ref : >ocumentos/Facultad/Tesis/models/bdb/data/interim/dmps_test_labels.mlf
#   Rec : >gfogwil/Documentos/Facultad/Tesis/models/bdb/data/interim/results.mlf
# ------------------------ Overall Results --------------------------
# SENT: %Correct=70.93 [H=183, S=75, N=258]
# WORD: %Corr=97.60, Acc=55.09 [H=326, D=8, S=0, I=142, N=334]
# ------------------------ Confusion Matrix -------------------------
#        e   n
#            e  Del [ %c / %e]
#    e  34   0    4
#   ne   0  292   4
# Ins   71  71
# ===================================================================
#
# mfcc: 0.19381919607069836
#
# Pruning-Off
#
# Pruning-Off
#
# Pruning-Off
#
#
# ====================== HTK Results Analysis =======================
#   Date: Tue Sep 14 20:32:08 2021
#   Ref : >ocumentos/Facultad/Tesis/models/bdb/data/interim/dmps_test_labels.mlf
#   Rec : >gfogwil/Documentos/Facultad/Tesis/models/bdb/data/interim/results.mlf
# ------------------------ Overall Results --------------------------
# SENT: %Correct=69.77 [H=180, S=78, N=258]
# WORD: %Corr=97.60, Acc=53.29 [H=326, D=8, S=0, I=148, N=334]
# ------------------------ Confusion Matrix -------------------------
#        e   n
#            e  Del [ %c / %e]
#    e  34   0    4
#   ne   0  292   4
# Ins   74  74
# ===================================================================
#
# mfcc: 0.2085761154025067
#
# Pruning-Off
#
# Pruning-Off
#
# Pruning-Off
#
#
# ====================== HTK Results Analysis =======================
#   Date: Tue Sep 14 20:32:18 2021
#   Ref : >ocumentos/Facultad/Tesis/models/bdb/data/interim/dmps_test_labels.mlf
#   Rec : >gfogwil/Documentos/Facultad/Tesis/models/bdb/data/interim/results.mlf
# ------------------------ Overall Results --------------------------
# SENT: %Correct=70.16 [H=181, S=77, N=258]
# WORD: %Corr=98.80, Acc=53.89 [H=330, D=4, S=0, I=150, N=334]
# ------------------------ Confusion Matrix -------------------------
#        e   n
#            e  Del [ %c / %e]
#    e  36   0    2
#   ne   0  294   2
# Ins   75  75
# ===================================================================
#
# mfcc: 0.23220364830702428
#
# Pruning-Off
#
# Pruning-Off
#
# Pruning-Off
#
#
# ====================== HTK Results Analysis =======================
#   Date: Tue Sep 14 20:32:31 2021
#   Ref : >ocumentos/Facultad/Tesis/models/bdb/data/interim/dmps_test_labels.mlf
#   Rec : >gfogwil/Documentos/Facultad/Tesis/models/bdb/data/interim/results.mlf
# ------------------------ Overall Results --------------------------
# SENT: %Correct=73.26 [H=189, S=69, N=258]
# WORD: %Corr=98.20, Acc=58.68 [H=328, D=6, S=0, I=132, N=334]
# ------------------------ Confusion Matrix -------------------------
#        e   n
#            e  Del [ %c / %e]
#    e  35   0    3
#   ne   0  293   3
# Ins   66  66
# ===================================================================
#
# mfcc: 0.23029828450849243

# %% [markdown]
# ## Analizo los resultados

# %%
# !HResults -A -T 1 -f -p  -t -I /home/gfogwil/Documentos/Facultad/Tesis/models/bdb/data/interim/dmps_test_labels.mlf /home/gfogwil/Documentos/Facultad/Tesis/models/bdb/npfd/models/HTK/misc/monophones ../../data/interim/results.mlf > ../../npfd/models/HTK/analisis_PP/listado_alineamientos.txt

# %%
# !grep "N=  1]" ../../npfd/models/HTK/analisis_PP/listado_alineamientos.txt | wc
# !grep "N=  2]" ../../npfd/models/HTK/analisis_PP/listado_alineamientos.txt | wc
# !grep "N=  3]" ../../npfd/models/HTK/analisis_PP/listado_alineamientos.txt | wc
# Out:
#     220    2640   15026
#       0       0       0
#      38     459    2584

# %%
! awk -f ../../npfd/models/HTK/analisis_PP/f.awk ../../npfd/models/HTK/analisis_PP/listado_alineamientos.txt
# Out:
# EVENT {0}:18-10-23.rec:  100.00(100.00)  [H=   3, D=  0, S=  0, I=  0, N=  3]
# EVENT {1}:19-04-24.rec:  100.00(100.00)  [H=   3, D=  0, S=  0, I=  0, N=  3]
# EVENT {2}:18-12-05.rec:  100.00(100.00)  [H=   3, D=  0, S=  0, I=  0, N=  3]
# EVENT {3}:17-01-28.rec:  100.00(100.00)  [H=   3, D=  0, S=  0, I=  0, N=  3]
# EVENT {4}:17-11-15.rec:  100.00(100.00)  [H=   3, D=  0, S=  0, I=  0, N=  3]
# EVENT {5}:16-11-25.rec:  100.00(100.00)  [H=   3, D=  0, S=  0, I=  0, N=  3]
# EVENT {6}:15-03-15.rec:  100.00(100.00)  [H=   3, D=  0, S=  0, I=  0, N=  3]
# EVENT {7}:17-12-03.rec:  100.00(100.00)  [H=   3, D=  0, S=  0, I=  0, N=  3]
# EVENT {8}:16-04-06.rec:   33.33( 33.33)  [H=   1, D=  2, S=  0, I=  0, N=  3]
# Aligned transcription: /home/gfogwil/Documentos/Facultad/Tesis/models/bdb/data/interim/dmps_test_D_A/16-04-06.lab vs /home/gfogwil/Documentos/Facultad/Tesis/models/bdb/data/interim/dmps_test_D_A/16-04-06.rec
#  LAB: ne e ne
#  REC:      ne : FALSO NEGATIVO!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!
# EVENT {9}:19-10-26.rec:  100.00(100.00)  [H=   3, D=  0, S=  0, I=  0, N=  3]
# EVENT {10}:20-01-11.rec:  100.00(100.00)  [H=   3, D=  0, S=  0, I=  0, N=  3]
# EVENT {11}:15-09-17.rec:  100.00(100.00)  [H=   3, D=  0, S=  0, I=  0, N=  3]
# EVENT {12}:16-12-21.rec:   33.33( 33.33)  [H=   1, D=  2, S=  0, I=  0, N=  3]
# Aligned transcription: /home/gfogwil/Documentos/Facultad/Tesis/models/bdb/data/interim/dmps_test_D_A/16-12-21.lab vs /home/gfogwil/Documentos/Facultad/Tesis/models/bdb/data/interim/dmps_test_D_A/16-12-21.rec
#  LAB: ne e ne
#  REC:      ne : FALSO NEGATIVO!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!
# EVENT {13}:18-01-20.rec:  100.00(100.00)  [H=   3, D=  0, S=  0, I=  0, N=  3]
# EVENT {14}:19-11-10.rec:  100.00(100.00)  [H=   3, D=  0, S=  0, I=  0, N=  3]
# EVENT {15}:20-03-30.rec:  100.00(100.00)  [H=   3, D=  0, S=  0, I=  0, N=  3]
# EVENT {16}:17-01-02.rec:  100.00(100.00)  [H=   3, D=  0, S=  0, I=  0, N=  3]
# EVENT {17}:19-12-02.rec:  100.00(100.00)  [H=   3, D=  0, S=  0, I=  0, N=  3]
# EVENT {18}:17-12-25.rec:  100.00(100.00)  [H=   3, D=  0, S=  0, I=  0, N=  3]
# EVENT {19}:18-11-22.rec:  100.00(100.00)  [H=   3, D=  0, S=  0, I=  0, N=  3]
# EVENT {20}:17-02-06.rec:  100.00(100.00)  [H=   3, D=  0, S=  0, I=  0, N=  3]
# EVENT {21}:19-05-04.rec:  100.00(100.00)  [H=   3, D=  0, S=  0, I=  0, N=  3]
# EVENT {22}:17-03-24.rec:  100.00(100.00)  [H=   3, D=  0, S=  0, I=  0, N=  3]
# EVENT {23}:18-12-06.rec:  100.00(100.00)  [H=   3, D=  0, S=  0, I=  0, N=  3]
# EVENT {24}:13-02-05.rec:  100.00(100.00)  [H=   3, D=  0, S=  0, I=  0, N=  3]
# EVENT {25}:19-01-21.rec:  100.00(100.00)  [H=   3, D=  0, S=  0, I=  0, N=  3]
# EVENT {26}:16-09-20.rec:   33.33( 33.33)  [H=   1, D=  2, S=  0, I=  0, N=  3]
# Aligned transcription: /home/gfogwil/Documentos/Facultad/Tesis/models/bdb/data/interim/dmps_test_D_A/16-09-20.lab vs /home/gfogwil/Documentos/Facultad/Tesis/models/bdb/data/interim/dmps_test_D_A/16-09-20.rec
#  LAB: ne e ne
#  REC:      ne : FALSO NEGATIVO!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!
# EVENT {27}:20-03-06.rec:  100.00(100.00)  [H=   3, D=  0, S=  0, I=  0, N=  3]
# EVENT {28}:15-10-25.rec:  100.00(100.00)  [H=   3, D=  0, S=  0, I=  0, N=  3]
# EVENT {29}:18-11-11.rec:  100.00(100.00)  [H=   3, D=  0, S=  0, I=  0, N=  3]
# EVENT {30}:17-12-20.rec:  100.00(100.00)  [H=   3, D=  0, S=  0, I=  0, N=  3]
# EVENT {31}:19-03-17.rec:  100.00(100.00)  [H=   3, D=  0, S=  0, I=  0, N=  3]
# EVENT {32}:20-01-05.rec:  100.00(100.00)  [H=   3, D=  0, S=  0, I=  0, N=  3]
# EVENT {33}:17-01-08.rec:  100.00(100.00)  [H=   3, D=  0, S=  0, I=  0, N=  3]
# EVENT {34}:17-02-09.rec:  100.00(100.00)  [H=   3, D=  0, S=  0, I=  0, N=  3]
# EVENT {35}:15-02-14.rec:  100.00(100.00)  [H=   3, D=  0, S=  0, I=  0, N=  3]
# EVENT {36}:17-03-26.rec:  100.00(100.00)  [H=   3, D=  0, S=  0, I=  0, N=  3]
# EVENT {37}:18-01-24.rec:  100.00(100.00)  [H=   3, D=  0, S=  0, I=  0, N=  3]
# Cantidad de días con eventos: 38
# Cantidad de falsos negativos: 3

# %%
! awk -f ../../npfd/models/HTK/analisis_PP/fnoevent.awk ../../npfd/models/HTK/analisis_PP/listado_alineamientos.txt
# Out:
# NO EVENT {0}:20-04-27.rec:  100.00(100.00)  [H=   1, D=  0, S=  0, I=  0, N=  1]
# NO EVENT {1}:20-05-07.rec:  100.00(100.00)  [H=   1, D=  0, S=  0, I=  0, N=  1]
# NO EVENT {2}:18-01-13.rec:  100.00(100.00)  [H=   1, D=  0, S=  0, I=  0, N=  1]
# NO EVENT {3}:20-06-11.rec:  100.00(100.00)  [H=   1, D=  0, S=  0, I=  0, N=  1]
# NO EVENT {4}:17-05-14.rec:  100.00(100.00)  [H=   1, D=  0, S=  0, I=  0, N=  1]
# NO EVENT {5}:15-04-21.rec:  100.00(100.00)  [H=   1, D=  0, S=  0, I=  0, N=  1]
# NO EVENT {6}:15-09-14.rec:  100.00(100.00)  [H=   1, D=  0, S=  0, I=  0, N=  1]
# NO EVENT {7}:20-02-22.rec:  100.00(-100.00)  [H=   1, D=  0, S=  0, I=  2, N=  1]
# Aligned transcription: /home/gfogwil/Documentos/Facultad/Tesis/models/bdb/data/interim/dmps_test_D_A/20-02-22.lab vs /home/gfogwil/Documentos/Facultad/Tesis/models/bdb/data/interim/dmps_test_D_A/20-02-22.rec
#  LAB:      ne
#  REC: ne e ne : FALSO POSITIVO!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!
# NO EVENT {8}:15-08-27.rec:  100.00(100.00)  [H=   1, D=  0, S=  0, I=  0, N=  1]
# NO EVENT {9}:14-02-07.rec:  100.00(100.00)  [H=   1, D=  0, S=  0, I=  0, N=  1]
# NO EVENT {10}:15-05-19.rec:  100.00(100.00)  [H=   1, D=  0, S=  0, I=  0, N=  1]
# NO EVENT {11}:18-03-25.rec:  100.00(100.00)  [H=   1, D=  0, S=  0, I=  0, N=  1]
# NO EVENT {12}:18-06-16.rec:  100.00(100.00)  [H=   1, D=  0, S=  0, I=  0, N=  1]
# NO EVENT {13}:20-03-01.rec:  100.00(-100.00)  [H=   1, D=  0, S=  0, I=  2, N=  1]
# Aligned transcription: /home/gfogwil/Documentos/Facultad/Tesis/models/bdb/data/interim/dmps_test_D_A/20-03-01.lab vs /home/gfogwil/Documentos/Facultad/Tesis/models/bdb/data/interim/dmps_test_D_A/20-03-01.rec
#  LAB:      ne
#  REC: ne e ne : FALSO POSITIVO!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!
# NO EVENT {14}:16-04-02.rec:  100.00(100.00)  [H=   1, D=  0, S=  0, I=  0, N=  1]
# NO EVENT {15}:16-05-24.rec:  100.00(100.00)  [H=   1, D=  0, S=  0, I=  0, N=  1]
# NO EVENT {16}:16-11-12.rec:  100.00(-100.00)  [H=   1, D=  0, S=  0, I=  2, N=  1]
# Aligned transcription: /home/gfogwil/Documentos/Facultad/Tesis/models/bdb/data/interim/dmps_test_D_A/16-11-12.lab vs /home/gfogwil/Documentos/Facultad/Tesis/models/bdb/data/interim/dmps_test_D_A/16-11-12.rec
#  LAB:      ne
#  REC: ne e ne : FALSO POSITIVO!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!
# NO EVENT {17}:18-12-16.rec:  100.00(100.00)  [H=   1, D=  0, S=  0, I=  0, N=  1]
# NO EVENT {18}:16-09-04.rec:  100.00(100.00)  [H=   1, D=  0, S=  0, I=  0, N=  1]
# NO EVENT {19}:16-10-10.rec:  100.00(-100.00)  [H=   1, D=  0, S=  0, I=  2, N=  1]
# Aligned transcription: /home/gfogwil/Documentos/Facultad/Tesis/models/bdb/data/interim/dmps_test_D_A/16-10-10.lab vs /home/gfogwil/Documentos/Facultad/Tesis/models/bdb/data/interim/dmps_test_D_A/16-10-10.rec
#  LAB:      ne
#  REC: ne e ne : FALSO POSITIVO!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!
# NO EVENT {20}:19-12-06.rec:  100.00(100.00)  [H=   1, D=  0, S=  0, I=  0, N=  1]
# NO EVENT {21}:16-04-15.rec:  100.00(100.00)  [H=   1, D=  0, S=  0, I=  0, N=  1]
# NO EVENT {22}:17-10-20.rec:  100.00(100.00)  [H=   1, D=  0, S=  0, I=  0, N=  1]
# NO EVENT {23}:19-04-28.rec:  100.00(100.00)  [H=   1, D=  0, S=  0, I=  0, N=  1]
# NO EVENT {24}:20-04-01.rec:  100.00(100.00)  [H=   1, D=  0, S=  0, I=  0, N=  1]
# NO EVENT {25}:17-04-19.rec:  100.00(100.00)  [H=   1, D=  0, S=  0, I=  0, N=  1]
# NO EVENT {26}:18-10-12.rec:  100.00(100.00)  [H=   1, D=  0, S=  0, I=  0, N=  1]
# NO EVENT {27}:20-07-29.rec:  100.00(100.00)  [H=   1, D=  0, S=  0, I=  0, N=  1]
# NO EVENT {28}:17-04-25.rec:  100.00(-100.00)  [H=   1, D=  0, S=  0, I=  2, N=  1]
# Aligned transcription: /home/gfogwil/Documentos/Facultad/Tesis/models/bdb/data/interim/dmps_test_D_A/17-04-25.lab vs /home/gfogwil/Documentos/Facultad/Tesis/models/bdb/data/interim/dmps_test_D_A/17-04-25.rec
#  LAB:      ne
#  REC: ne e ne : FALSO POSITIVO!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!
# NO EVENT {29}:19-10-10.rec:  100.00(100.00)  [H=   1, D=  0, S=  0, I=  0, N=  1]
# NO EVENT {30}:18-06-24.rec:  100.00(100.00)  [H=   1, D=  0, S=  0, I=  0, N=  1]
# NO EVENT {31}:19-09-26.rec:  100.00(100.00)  [H=   1, D=  0, S=  0, I=  0, N=  1]
# NO EVENT {32}:17-10-13.rec:  100.00(-100.00)  [H=   1, D=  0, S=  0, I=  2, N=  1]
# Aligned transcription: /home/gfogwil/Documentos/Facultad/Tesis/models/bdb/data/interim/dmps_test_D_A/17-10-13.lab vs /home/gfogwil/Documentos/Facultad/Tesis/models/bdb/data/interim/dmps_test_D_A/17-10-13.rec
#  LAB:      ne
#  REC: ne e ne : FALSO POSITIVO!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!
# NO EVENT {33}:19-04-14.rec:  100.00(100.00)  [H=   1, D=  0, S=  0, I=  0, N=  1]
# NO EVENT {34}:19-11-17.rec:  100.00(-100.00)  [H=   1, D=  0, S=  0, I=  2, N=  1]
# Aligned transcription: /home/gfogwil/Documentos/Facultad/Tesis/models/bdb/data/interim/dmps_test_D_A/19-11-17.lab vs /home/gfogwil/Documentos/Facultad/Tesis/models/bdb/data/interim/dmps_test_D_A/19-11-17.rec
#  LAB:      ne
#  REC: ne e ne : FALSO POSITIVO!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!
# NO EVENT {35}:15-09-03.rec:  100.00(100.00)  [H=   1, D=  0, S=  0, I=  0, N=  1]
# NO EVENT {36}:17-01-24.rec:  100.00(100.00)  [H=   1, D=  0, S=  0, I=  0, N=  1]
# NO EVENT {37}:20-01-01.rec:  100.00(-100.00)  [H=   1, D=  0, S=  0, I=  2, N=  1]
# Aligned transcription: /home/gfogwil/Documentos/Facultad/Tesis/models/bdb/data/interim/dmps_test_D_A/20-01-01.lab vs /home/gfogwil/Documentos/Facultad/Tesis/models/bdb/data/interim/dmps_test_D_A/20-01-01.rec
#  LAB:      ne
#  REC: ne e ne : FALSO POSITIVO!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!
# NO EVENT {38}:19-10-09.rec:  100.00(100.00)  [H=   1, D=  0, S=  0, I=  0, N=  1]
# NO EVENT {39}:20-05-21.rec:  100.00(100.00)  [H=   1, D=  0, S=  0, I=  0, N=  1]
# NO EVENT {40}:19-08-06.rec:  100.00(100.00)  [H=   1, D=  0, S=  0, I=  0, N=  1]
# NO EVENT {41}:19-05-06.rec:  100.00(100.00)  [H=   1, D=  0, S=  0, I=  0, N=  1]
# NO EVENT {42}:18-10-02.rec:  100.00(-100.00)  [H=   1, D=  0, S=  0, I=  2, N=  1]
# Aligned transcription: /home/gfogwil/Documentos/Facultad/Tesis/models/bdb/data/interim/dmps_test_D_A/18-10-02.lab vs /home/gfogwil/Documentos/Facultad/Tesis/models/bdb/data/interim/dmps_test_D_A/18-10-02.rec
#  LAB:      ne
#  REC: ne e ne : FALSO POSITIVO!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!
# NO EVENT {43}:18-05-30.rec:  100.00(100.00)  [H=   1, D=  0, S=  0, I=  0, N=  1]
# NO EVENT {44}:20-03-20.rec:  100.00(100.00)  [H=   1, D=  0, S=  0, I=  0, N=  1]
# NO EVENT {45}:20-03-25.rec:  100.00(-100.00)  [H=   1, D=  0, S=  0, I=  2, N=  1]
# Aligned transcription: /home/gfogwil/Documentos/Facultad/Tesis/models/bdb/data/interim/dmps_test_D_A/20-03-25.lab vs /home/gfogwil/Documentos/Facultad/Tesis/models/bdb/data/interim/dmps_test_D_A/20-03-25.rec
#  LAB:      ne
#  REC: ne e ne : FALSO POSITIVO!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!
# NO EVENT {46}:18-11-17.rec:  100.00(100.00)  [H=   1, D=  0, S=  0, I=  0, N=  1]
# NO EVENT {47}:19-11-06.rec:  100.00(100.00)  [H=   1, D=  0, S=  0, I=  0, N=  1]
# NO EVENT {48}:15-04-29.rec:  100.00(100.00)  [H=   1, D=  0, S=  0, I=  0, N=  1]
# NO EVENT {49}:18-07-09.rec:  100.00(100.00)  [H=   1, D=  0, S=  0, I=  0, N=  1]
# NO EVENT {50}:17-09-29.rec:  100.00(100.00)  [H=   1, D=  0, S=  0, I=  0, N=  1]
# NO EVENT {51}:16-10-03.rec:  100.00(-100.00)  [H=   1, D=  0, S=  0, I=  2, N=  1]
# Aligned transcription: /home/gfogwil/Documentos/Facultad/Tesis/models/bdb/data/interim/dmps_test_D_A/16-10-03.lab vs /home/gfogwil/Documentos/Facultad/Tesis/models/bdb/data/interim/dmps_test_D_A/16-10-03.rec
#  LAB:      ne
#  REC: ne e ne : FALSO POSITIVO!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!
# NO EVENT {52}:17-04-15.rec:  100.00(100.00)  [H=   1, D=  0, S=  0, I=  0, N=  1]
# NO EVENT {53}:16-02-24.rec:  100.00(100.00)  [H=   1, D=  0, S=  0, I=  0, N=  1]
# NO EVENT {54}:16-08-30.rec:  100.00(100.00)  [H=   1, D=  0, S=  0, I=  0, N=  1]
# NO EVENT {55}:19-10-20.rec:  100.00(-100.00)  [H=   1, D=  0, S=  0, I=  2, N=  1]
# Aligned transcription: /home/gfogwil/Documentos/Facultad/Tesis/models/bdb/data/interim/dmps_test_D_A/19-10-20.lab vs /home/gfogwil/Documentos/Facultad/Tesis/models/bdb/data/interim/dmps_test_D_A/19-10-20.rec
#  LAB:      ne
#  REC: ne e ne : FALSO POSITIVO!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!
# NO EVENT {56}:17-03-09.rec:  100.00(-100.00)  [H=   1, D=  0, S=  0, I=  2, N=  1]
# Aligned transcription: /home/gfogwil/Documentos/Facultad/Tesis/models/bdb/data/interim/dmps_test_D_A/17-03-09.lab vs /home/gfogwil/Documentos/Facultad/Tesis/models/bdb/data/interim/dmps_test_D_A/17-03-09.rec
#  LAB:      ne
#  REC: ne e ne : FALSO POSITIVO!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!
# NO EVENT {57}:18-07-25.rec:  100.00(100.00)  [H=   1, D=  0, S=  0, I=  0, N=  1]
# NO EVENT {58}:19-05-14.rec:  100.00(100.00)  [H=   1, D=  0, S=  0, I=  0, N=  1]
# NO EVENT {59}:19-08-22.rec:  100.00(100.00)  [H=   1, D=  0, S=  0, I=  0, N=  1]
# NO EVENT {60}:19-01-24.rec:  100.00(100.00)  [H=   1, D=  0, S=  0, I=  0, N=  1]
# NO EVENT {61}:16-11-29.rec:  100.00(100.00)  [H=   1, D=  0, S=  0, I=  0, N=  1]
# NO EVENT {62}:18-07-12.rec:  100.00(100.00)  [H=   1, D=  0, S=  0, I=  0, N=  1]
# NO EVENT {63}:18-07-07.rec:  100.00(100.00)  [H=   1, D=  0, S=  0, I=  0, N=  1]
# NO EVENT {64}:19-09-29.rec:  100.00(100.00)  [H=   1, D=  0, S=  0, I=  0, N=  1]
# NO EVENT {65}:15-06-30.rec:  100.00(100.00)  [H=   1, D=  0, S=  0, I=  0, N=  1]
# NO EVENT {66}:15-10-30.rec:  100.00(100.00)  [H=   1, D=  0, S=  0, I=  0, N=  1]
# NO EVENT {67}:19-08-20.rec:  100.00(100.00)  [H=   1, D=  0, S=  0, I=  0, N=  1]
# NO EVENT {68}:19-05-05.rec:  100.00(100.00)  [H=   1, D=  0, S=  0, I=  0, N=  1]
# NO EVENT {69}:19-09-05.rec:  100.00(-100.00)  [H=   1, D=  0, S=  0, I=  2, N=  1]
# Aligned transcription: /home/gfogwil/Documentos/Facultad/Tesis/models/bdb/data/interim/dmps_test_D_A/19-09-05.lab vs /home/gfogwil/Documentos/Facultad/Tesis/models/bdb/data/interim/dmps_test_D_A/19-09-05.rec
#  LAB:      ne
#  REC: ne e ne : FALSO POSITIVO!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!
# NO EVENT {70}:20-05-01.rec:  100.00(100.00)  [H=   1, D=  0, S=  0, I=  0, N=  1]
# NO EVENT {71}:15-06-23.rec:  100.00(100.00)  [H=   1, D=  0, S=  0, I=  0, N=  1]
# NO EVENT {72}:17-10-08.rec:  100.00(-100.00)  [H=   1, D=  0, S=  0, I=  2, N=  1]
# Aligned transcription: /home/gfogwil/Documentos/Facultad/Tesis/models/bdb/data/interim/dmps_test_D_A/17-10-08.lab vs /home/gfogwil/Documentos/Facultad/Tesis/models/bdb/data/interim/dmps_test_D_A/17-10-08.rec
#  LAB:      ne
#  REC: ne e ne : FALSO POSITIVO!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!
# NO EVENT {73}:15-10-31.rec:  100.00(100.00)  [H=   1, D=  0, S=  0, I=  0, N=  1]
# NO EVENT {74}:18-07-08.rec:  100.00(100.00)  [H=   1, D=  0, S=  0, I=  0, N=  1]
# NO EVENT {75}:16-05-28.rec:  100.00(100.00)  [H=   1, D=  0, S=  0, I=  0, N=  1]
# NO EVENT {76}:19-09-28.rec:  100.00(100.00)  [H=   1, D=  0, S=  0, I=  0, N=  1]
# NO EVENT {77}:18-04-22.rec:  100.00(100.00)  [H=   1, D=  0, S=  0, I=  0, N=  1]
# NO EVENT {78}:18-12-01.rec:  100.00(-100.00)  [H=   1, D=  0, S=  0, I=  2, N=  1]
# Aligned transcription: /home/gfogwil/Documentos/Facultad/Tesis/models/bdb/data/interim/dmps_test_D_A/18-12-01.lab vs /home/gfogwil/Documentos/Facultad/Tesis/models/bdb/data/interim/dmps_test_D_A/18-12-01.rec
#  LAB:      ne
#  REC: ne e ne : FALSO POSITIVO!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!
# NO EVENT {79}:20-01-21.rec:  100.00(-100.00)  [H=   1, D=  0, S=  0, I=  2, N=  1]
# Aligned transcription: /home/gfogwil/Documentos/Facultad/Tesis/models/bdb/data/interim/dmps_test_D_A/20-01-21.lab vs /home/gfogwil/Documentos/Facultad/Tesis/models/bdb/data/interim/dmps_test_D_A/20-01-21.rec
#  LAB:      ne
#  REC: ne e ne : FALSO POSITIVO!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!
# NO EVENT {80}:18-04-12.rec:  100.00(100.00)  [H=   1, D=  0, S=  0, I=  0, N=  1]
# NO EVENT {81}:18-12-21.rec:  100.00(-100.00)  [H=   1, D=  0, S=  0, I=  2, N=  1]
# Aligned transcription: /home/gfogwil/Documentos/Facultad/Tesis/models/bdb/data/interim/dmps_test_D_A/18-12-21.lab vs /home/gfogwil/Documentos/Facultad/Tesis/models/bdb/data/interim/dmps_test_D_A/18-12-21.rec
#  LAB:      ne
#  REC: ne e ne : FALSO POSITIVO!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!
# NO EVENT {82}:17-10-14.rec:  100.00(100.00)  [H=   1, D=  0, S=  0, I=  0, N=  1]
# NO EVENT {83}:15-08-20.rec:  100.00(100.00)  [H=   1, D=  0, S=  0, I=  0, N=  1]
# NO EVENT {84}:16-06-30.rec:  100.00(100.00)  [H=   1, D=  0, S=  0, I=  0, N=  1]
# NO EVENT {85}:17-12-15.rec:  100.00(-100.00)  [H=   1, D=  0, S=  0, I=  2, N=  1]
# Aligned transcription: /home/gfogwil/Documentos/Facultad/Tesis/models/bdb/data/interim/dmps_test_D_A/17-12-15.lab vs /home/gfogwil/Documentos/Facultad/Tesis/models/bdb/data/interim/dmps_test_D_A/17-12-15.rec
#  LAB:      ne
#  REC: ne e ne : FALSO POSITIVO!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!
# NO EVENT {86}:18-11-24.rec:  100.00(100.00)  [H=   1, D=  0, S=  0, I=  0, N=  1]
# NO EVENT {87}:18-10-30.rec:  100.00(-100.00)  [H=   1, D=  0, S=  0, I=  2, N=  1]
# Aligned transcription: /home/gfogwil/Documentos/Facultad/Tesis/models/bdb/data/interim/dmps_test_D_A/18-10-30.lab vs /home/gfogwil/Documentos/Facultad/Tesis/models/bdb/data/interim/dmps_test_D_A/18-10-30.rec
#  LAB:      ne
#  REC: ne e ne : FALSO POSITIVO!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!
# NO EVENT {88}:16-08-22.rec:  100.00(100.00)  [H=   1, D=  0, S=  0, I=  0, N=  1]
# NO EVENT {89}:20-03-19.rec:  100.00(100.00)  [H=   1, D=  0, S=  0, I=  0, N=  1]
# NO EVENT {90}:17-03-31.rec:  100.00(-100.00)  [H=   1, D=  0, S=  0, I=  2, N=  1]
# Aligned transcription: /home/gfogwil/Documentos/Facultad/Tesis/models/bdb/data/interim/dmps_test_D_A/17-03-31.lab vs /home/gfogwil/Documentos/Facultad/Tesis/models/bdb/data/interim/dmps_test_D_A/17-03-31.rec
#  LAB:      ne
#  REC: ne e ne : FALSO POSITIVO!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!
# NO EVENT {91}:19-10-12.rec:  100.00(100.00)  [H=   1, D=  0, S=  0, I=  0, N=  1]
# NO EVENT {92}:16-09-14.rec:  100.00(100.00)  [H=   1, D=  0, S=  0, I=  0, N=  1]
# NO EVENT {93}:17-09-26.rec:  100.00(100.00)  [H=   1, D=  0, S=  0, I=  0, N=  1]
# NO EVENT {94}:18-05-07.rec:  100.00(100.00)  [H=   1, D=  0, S=  0, I=  0, N=  1]
# NO EVENT {95}:20-05-23.rec:  100.00(100.00)  [H=   1, D=  0, S=  0, I=  0, N=  1]
# NO EVENT {96}:20-04-03.rec:  100.00(100.00)  [H=   1, D=  0, S=  0, I=  0, N=  1]
# NO EVENT {97}:17-02-21.rec:  100.00(-100.00)  [H=   1, D=  0, S=  0, I=  2, N=  1]
# Aligned transcription: /home/gfogwil/Documentos/Facultad/Tesis/models/bdb/data/interim/dmps_test_D_A/17-02-21.lab vs /home/gfogwil/Documentos/Facultad/Tesis/models/bdb/data/interim/dmps_test_D_A/17-02-21.rec
#  LAB:      ne
#  REC: ne e ne : FALSO POSITIVO!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!
# NO EVENT {98}:18-01-14.rec:  100.00(100.00)  [H=   1, D=  0, S=  0, I=  0, N=  1]
# NO EVENT {99}:16-04-21.rec:  100.00(100.00)  [H=   1, D=  0, S=  0, I=  0, N=  1]
# NO EVENT {100}:19-07-05.rec:  100.00(100.00)  [H=   1, D=  0, S=  0, I=  0, N=  1]
# NO EVENT {101}:20-08-14.rec:  100.00(100.00)  [H=   1, D=  0, S=  0, I=  0, N=  1]
# NO EVENT {102}:17-02-26.rec:  100.00(100.00)  [H=   1, D=  0, S=  0, I=  0, N=  1]
# NO EVENT {103}:19-04-02.rec:  100.00(-100.00)  [H=   1, D=  0, S=  0, I=  2, N=  1]
# Aligned transcription: /home/gfogwil/Documentos/Facultad/Tesis/models/bdb/data/interim/dmps_test_D_A/19-04-02.lab vs /home/gfogwil/Documentos/Facultad/Tesis/models/bdb/data/interim/dmps_test_D_A/19-04-02.rec
#  LAB:      ne
#  REC: ne e ne : FALSO POSITIVO!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!
# NO EVENT {104}:20-01-03.rec:  100.00(-100.00)  [H=   1, D=  0, S=  0, I=  2, N=  1]
# Aligned transcription: /home/gfogwil/Documentos/Facultad/Tesis/models/bdb/data/interim/dmps_test_D_A/20-01-03.lab vs /home/gfogwil/Documentos/Facultad/Tesis/models/bdb/data/interim/dmps_test_D_A/20-01-03.rec
#  LAB:      ne
#  REC: ne e ne : FALSO POSITIVO!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!
# NO EVENT {105}:16-05-26.rec:  100.00(-100.00)  [H=   1, D=  0, S=  0, I=  2, N=  1]
# Aligned transcription: /home/gfogwil/Documentos/Facultad/Tesis/models/bdb/data/interim/dmps_test_D_A/16-05-26.lab vs /home/gfogwil/Documentos/Facultad/Tesis/models/bdb/data/interim/dmps_test_D_A/16-05-26.rec
#  LAB:      ne
#  REC: ne e ne : FALSO POSITIVO!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!
# NO EVENT {106}:20-06-12.rec:  100.00(100.00)  [H=   1, D=  0, S=  0, I=  0, N=  1]
# NO EVENT {107}:19-10-17.rec:  100.00(-100.00)  [H=   1, D=  0, S=  0, I=  2, N=  1]
# Aligned transcription: /home/gfogwil/Documentos/Facultad/Tesis/models/bdb/data/interim/dmps_test_D_A/19-10-17.lab vs /home/gfogwil/Documentos/Facultad/Tesis/models/bdb/data/interim/dmps_test_D_A/19-10-17.rec
#  LAB:      ne
#  REC: ne e ne : FALSO POSITIVO!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!
# NO EVENT {108}:20-01-10.rec:  100.00(100.00)  [H=   1, D=  0, S=  0, I=  0, N=  1]
# NO EVENT {109}:19-12-09.rec:  100.00(-100.00)  [H=   1, D=  0, S=  0, I=  2, N=  1]
# Aligned transcription: /home/gfogwil/Documentos/Facultad/Tesis/models/bdb/data/interim/dmps_test_D_A/19-12-09.lab vs /home/gfogwil/Documentos/Facultad/Tesis/models/bdb/data/interim/dmps_test_D_A/19-12-09.rec
#  LAB:      ne
#  REC: ne e ne : FALSO POSITIVO!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!
# NO EVENT {110}:16-02-08.rec:  100.00(-100.00)  [H=   1, D=  0, S=  0, I=  2, N=  1]
# Aligned transcription: /home/gfogwil/Documentos/Facultad/Tesis/models/bdb/data/interim/dmps_test_D_A/16-02-08.lab vs /home/gfogwil/Documentos/Facultad/Tesis/models/bdb/data/interim/dmps_test_D_A/16-02-08.rec
#  LAB:      ne
#  REC: ne e ne : FALSO POSITIVO!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!
# NO EVENT {111}:19-06-04.rec:  100.00(-100.00)  [H=   1, D=  0, S=  0, I=  2, N=  1]
# Aligned transcription: /home/gfogwil/Documentos/Facultad/Tesis/models/bdb/data/interim/dmps_test_D_A/19-06-04.lab vs /home/gfogwil/Documentos/Facultad/Tesis/models/bdb/data/interim/dmps_test_D_A/19-06-04.rec
#  LAB:      ne
#  REC: ne e ne : FALSO POSITIVO!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!
# NO EVENT {112}:16-07-04.rec:  100.00(100.00)  [H=   1, D=  0, S=  0, I=  0, N=  1]
# NO EVENT {113}:19-10-23.rec:  100.00(-100.00)  [H=   1, D=  0, S=  0, I=  2, N=  1]
# Aligned transcription: /home/gfogwil/Documentos/Facultad/Tesis/models/bdb/data/interim/dmps_test_D_A/19-10-23.lab vs /home/gfogwil/Documentos/Facultad/Tesis/models/bdb/data/interim/dmps_test_D_A/19-10-23.rec
#  LAB:      ne
#  REC: ne e ne : FALSO POSITIVO!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!
# NO EVENT {114}:15-03-29.rec:  100.00(-100.00)  [H=   1, D=  0, S=  0, I=  2, N=  1]
# Aligned transcription: /home/gfogwil/Documentos/Facultad/Tesis/models/bdb/data/interim/dmps_test_D_A/15-03-29.lab vs /home/gfogwil/Documentos/Facultad/Tesis/models/bdb/data/interim/dmps_test_D_A/15-03-29.rec
#  LAB:      ne
#  REC: ne e ne : FALSO POSITIVO!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!
# NO EVENT {115}:18-07-24.rec:  100.00(100.00)  [H=   1, D=  0, S=  0, I=  0, N=  1]
# NO EVENT {116}:20-05-02.rec:  100.00(100.00)  [H=   1, D=  0, S=  0, I=  0, N=  1]
# NO EVENT {117}:16-08-06.rec:  100.00(100.00)  [H=   1, D=  0, S=  0, I=  0, N=  1]
# NO EVENT {118}:16-08-23.rec:  100.00(100.00)  [H=   1, D=  0, S=  0, I=  0, N=  1]
# NO EVENT {119}:18-01-03.rec:  100.00(100.00)  [H=   1, D=  0, S=  0, I=  0, N=  1]
# NO EVENT {120}:18-10-09.rec:  100.00(100.00)  [H=   1, D=  0, S=  0, I=  0, N=  1]
# NO EVENT {121}:16-10-09.rec:  100.00(-100.00)  [H=   1, D=  0, S=  0, I=  2, N=  1]
# Aligned transcription: /home/gfogwil/Documentos/Facultad/Tesis/models/bdb/data/interim/dmps_test_D_A/16-10-09.lab vs /home/gfogwil/Documentos/Facultad/Tesis/models/bdb/data/interim/dmps_test_D_A/16-10-09.rec
#  LAB:      ne
#  REC: ne e ne : FALSO POSITIVO!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!
# NO EVENT {122}:15-09-10.rec:  100.00(100.00)  [H=   1, D=  0, S=  0, I=  0, N=  1]
# NO EVENT {123}:17-03-02.rec:  100.00(100.00)  [H=   1, D=  0, S=  0, I=  0, N=  1]
# NO EVENT {124}:16-09-15.rec:  100.00(100.00)  [H=   1, D=  0, S=  0, I=  0, N=  1]
# NO EVENT {125}:16-09-08.rec:  100.00(100.00)  [H=   1, D=  0, S=  0, I=  0, N=  1]
# NO EVENT {126}:20-04-17.rec:  100.00(-100.00)  [H=   1, D=  0, S=  0, I=  2, N=  1]
# Aligned transcription: /home/gfogwil/Documentos/Facultad/Tesis/models/bdb/data/interim/dmps_test_D_A/20-04-17.lab vs /home/gfogwil/Documentos/Facultad/Tesis/models/bdb/data/interim/dmps_test_D_A/20-04-17.rec
#  LAB:      ne
#  REC: ne e ne : FALSO POSITIVO!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!
# NO EVENT {127}:16-04-20.rec:  100.00(100.00)  [H=   1, D=  0, S=  0, I=  0, N=  1]
# NO EVENT {128}:19-09-11.rec:  100.00(100.00)  [H=   1, D=  0, S=  0, I=  0, N=  1]
# NO EVENT {129}:20-05-28.rec:  100.00(100.00)  [H=   1, D=  0, S=  0, I=  0, N=  1]
# NO EVENT {130}:19-09-16.rec:  100.00(-100.00)  [H=   1, D=  0, S=  0, I=  2, N=  1]
# Aligned transcription: /home/gfogwil/Documentos/Facultad/Tesis/models/bdb/data/interim/dmps_test_D_A/19-09-16.lab vs /home/gfogwil/Documentos/Facultad/Tesis/models/bdb/data/interim/dmps_test_D_A/19-09-16.rec
#  LAB:      ne
#  REC: ne e ne : FALSO POSITIVO!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!
# NO EVENT {131}:16-06-18.rec:  100.00(100.00)  [H=   1, D=  0, S=  0, I=  0, N=  1]
# NO EVENT {132}:19-10-24.rec:  100.00(-100.00)  [H=   1, D=  0, S=  0, I=  2, N=  1]
# Aligned transcription: /home/gfogwil/Documentos/Facultad/Tesis/models/bdb/data/interim/dmps_test_D_A/19-10-24.lab vs /home/gfogwil/Documentos/Facultad/Tesis/models/bdb/data/interim/dmps_test_D_A/19-10-24.rec
#  LAB:      ne
#  REC: ne e ne : FALSO POSITIVO!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!
# NO EVENT {133}:15-07-09.rec:  100.00(100.00)  [H=   1, D=  0, S=  0, I=  0, N=  1]
# NO EVENT {134}:15-06-17.rec:  100.00(-100.00)  [H=   1, D=  0, S=  0, I=  2, N=  1]
# Aligned transcription: /home/gfogwil/Documentos/Facultad/Tesis/models/bdb/data/interim/dmps_test_D_A/15-06-17.lab vs /home/gfogwil/Documentos/Facultad/Tesis/models/bdb/data/interim/dmps_test_D_A/15-06-17.rec
#  LAB:      ne
#  REC: ne e ne : FALSO POSITIVO!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!
# NO EVENT {135}:16-09-13.rec:  100.00(100.00)  [H=   1, D=  0, S=  0, I=  0, N=  1]
# NO EVENT {136}:15-08-29.rec:  100.00(100.00)  [H=   1, D=  0, S=  0, I=  0, N=  1]
# NO EVENT {137}:16-04-13.rec:  100.00(100.00)  [H=   1, D=  0, S=  0, I=  0, N=  1]
# NO EVENT {138}:20-03-11.rec:  100.00(-100.00)  [H=   1, D=  0, S=  0, I=  2, N=  1]
# Aligned transcription: /home/gfogwil/Documentos/Facultad/Tesis/models/bdb/data/interim/dmps_test_D_A/20-03-11.lab vs /home/gfogwil/Documentos/Facultad/Tesis/models/bdb/data/interim/dmps_test_D_A/20-03-11.rec
#  LAB:      ne
#  REC: ne e ne : FALSO POSITIVO!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!
# NO EVENT {139}:18-08-17.rec:  100.00(100.00)  [H=   1, D=  0, S=  0, I=  0, N=  1]
# NO EVENT {140}:19-01-25.rec:  100.00(100.00)  [H=   1, D=  0, S=  0, I=  0, N=  1]
# NO EVENT {141}:18-03-14.rec:  100.00(100.00)  [H=   1, D=  0, S=  0, I=  0, N=  1]
# NO EVENT {142}:19-01-01.rec:  100.00(100.00)  [H=   1, D=  0, S=  0, I=  0, N=  1]
# NO EVENT {143}:18-06-09.rec:  100.00(100.00)  [H=   1, D=  0, S=  0, I=  0, N=  1]
# NO EVENT {144}:15-08-14.rec:  100.00(100.00)  [H=   1, D=  0, S=  0, I=  0, N=  1]
# NO EVENT {145}:19-06-02.rec:  100.00(100.00)  [H=   1, D=  0, S=  0, I=  0, N=  1]
# NO EVENT {146}:18-10-11.rec:  100.00(100.00)  [H=   1, D=  0, S=  0, I=  0, N=  1]
# NO EVENT {147}:19-09-21.rec:  100.00(100.00)  [H=   1, D=  0, S=  0, I=  0, N=  1]
# NO EVENT {148}:17-01-17.rec:  100.00(100.00)  [H=   1, D=  0, S=  0, I=  0, N=  1]
# NO EVENT {149}:18-01-11.rec:  100.00(100.00)  [H=   1, D=  0, S=  0, I=  0, N=  1]
# NO EVENT {150}:18-09-23.rec:  100.00(-100.00)  [H=   1, D=  0, S=  0, I=  2, N=  1]
# Aligned transcription: /home/gfogwil/Documentos/Facultad/Tesis/models/bdb/data/interim/dmps_test_D_A/18-09-23.lab vs /home/gfogwil/Documentos/Facultad/Tesis/models/bdb/data/interim/dmps_test_D_A/18-09-23.rec
#  LAB:      ne
#  REC: ne e ne : FALSO POSITIVO!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!
# NO EVENT {151}:20-03-23.rec:  100.00(100.00)  [H=   1, D=  0, S=  0, I=  0, N=  1]
# NO EVENT {152}:16-02-20.rec:  100.00(-100.00)  [H=   1, D=  0, S=  0, I=  2, N=  1]
# Aligned transcription: /home/gfogwil/Documentos/Facultad/Tesis/models/bdb/data/interim/dmps_test_D_A/16-02-20.lab vs /home/gfogwil/Documentos/Facultad/Tesis/models/bdb/data/interim/dmps_test_D_A/16-02-20.rec
#  LAB:      ne
#  REC: ne e ne : FALSO POSITIVO!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!
# NO EVENT {153}:20-01-16.rec:  100.00(-100.00)  [H=   1, D=  0, S=  0, I=  2, N=  1]
# Aligned transcription: /home/gfogwil/Documentos/Facultad/Tesis/models/bdb/data/interim/dmps_test_D_A/20-01-16.lab vs /home/gfogwil/Documentos/Facultad/Tesis/models/bdb/data/interim/dmps_test_D_A/20-01-16.rec
#  LAB:      ne
#  REC: ne e ne : FALSO POSITIVO!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!
# NO EVENT {154}:20-02-09.rec:  100.00(-100.00)  [H=   1, D=  0, S=  0, I=  2, N=  1]
# Aligned transcription: /home/gfogwil/Documentos/Facultad/Tesis/models/bdb/data/interim/dmps_test_D_A/20-02-09.lab vs /home/gfogwil/Documentos/Facultad/Tesis/models/bdb/data/interim/dmps_test_D_A/20-02-09.rec
#  LAB:      ne
#  REC: ne e ne : FALSO POSITIVO!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!
# NO EVENT {155}:16-09-06.rec:  100.00(100.00)  [H=   1, D=  0, S=  0, I=  0, N=  1]
# NO EVENT {156}:15-10-12.rec:  100.00(-100.00)  [H=   1, D=  0, S=  0, I=  2, N=  1]
# Aligned transcription: /home/gfogwil/Documentos/Facultad/Tesis/models/bdb/data/interim/dmps_test_D_A/15-10-12.lab vs /home/gfogwil/Documentos/Facultad/Tesis/models/bdb/data/interim/dmps_test_D_A/15-10-12.rec
#  LAB:      ne
#  REC: ne e ne : FALSO POSITIVO!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!
# NO EVENT {157}:15-03-28.rec:  100.00(-100.00)  [H=   1, D=  0, S=  0, I=  2, N=  1]
# Aligned transcription: /home/gfogwil/Documentos/Facultad/Tesis/models/bdb/data/interim/dmps_test_D_A/15-03-28.lab vs /home/gfogwil/Documentos/Facultad/Tesis/models/bdb/data/interim/dmps_test_D_A/15-03-28.rec
#  LAB:      ne
#  REC: ne e ne : FALSO POSITIVO!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!
# NO EVENT {158}:17-10-15.rec:  100.00(100.00)  [H=   1, D=  0, S=  0, I=  0, N=  1]
# NO EVENT {159}:16-11-07.rec:  100.00(-100.00)  [H=   1, D=  0, S=  0, I=  2, N=  1]
# Aligned transcription: /home/gfogwil/Documentos/Facultad/Tesis/models/bdb/data/interim/dmps_test_D_A/16-11-07.lab vs /home/gfogwil/Documentos/Facultad/Tesis/models/bdb/data/interim/dmps_test_D_A/16-11-07.rec
#  LAB:      ne
#  REC: ne e ne : FALSO POSITIVO!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!
# NO EVENT {160}:16-04-23.rec:  100.00(100.00)  [H=   1, D=  0, S=  0, I=  0, N=  1]
# NO EVENT {161}:19-12-18.rec:  100.00(-100.00)  [H=   1, D=  0, S=  0, I=  2, N=  1]
# Aligned transcription: /home/gfogwil/Documentos/Facultad/Tesis/models/bdb/data/interim/dmps_test_D_A/19-12-18.lab vs /home/gfogwil/Documentos/Facultad/Tesis/models/bdb/data/interim/dmps_test_D_A/19-12-18.rec
#  LAB:      ne
#  REC: ne e ne : FALSO POSITIVO!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!
# NO EVENT {162}:18-06-02.rec:  100.00(100.00)  [H=   1, D=  0, S=  0, I=  0, N=  1]
# NO EVENT {163}:18-07-21.rec:  100.00(100.00)  [H=   1, D=  0, S=  0, I=  0, N=  1]
# NO EVENT {164}:20-08-07.rec:  100.00(100.00)  [H=   1, D=  0, S=  0, I=  0, N=  1]
# NO EVENT {165}:19-05-22.rec:  100.00(100.00)  [H=   1, D=  0, S=  0, I=  0, N=  1]
# NO EVENT {166}:16-11-26.rec:  100.00(100.00)  [H=   1, D=  0, S=  0, I=  0, N=  1]
# NO EVENT {167}:18-07-18.rec:  100.00(100.00)  [H=   1, D=  0, S=  0, I=  0, N=  1]
# NO EVENT {168}:17-09-21.rec:  100.00(100.00)  [H=   1, D=  0, S=  0, I=  0, N=  1]
# NO EVENT {169}:18-09-30.rec:  100.00(-100.00)  [H=   1, D=  0, S=  0, I=  2, N=  1]
# Aligned transcription: /home/gfogwil/Documentos/Facultad/Tesis/models/bdb/data/interim/dmps_test_D_A/18-09-30.lab vs /home/gfogwil/Documentos/Facultad/Tesis/models/bdb/data/interim/dmps_test_D_A/18-09-30.rec
#  LAB:      ne
#  REC: ne e ne : FALSO POSITIVO!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!
# NO EVENT {170}:17-12-14.rec:  100.00(-100.00)  [H=   1, D=  0, S=  0, I=  2, N=  1]
# Aligned transcription: /home/gfogwil/Documentos/Facultad/Tesis/models/bdb/data/interim/dmps_test_D_A/17-12-14.lab vs /home/gfogwil/Documentos/Facultad/Tesis/models/bdb/data/interim/dmps_test_D_A/17-12-14.rec
#  LAB:      ne
#  REC: ne e ne : FALSO POSITIVO!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!
# NO EVENT {171}:20-07-24.rec:  100.00(100.00)  [H=   1, D=  0, S=  0, I=  0, N=  1]
# NO EVENT {172}:16-08-16.rec:  100.00(100.00)  [H=   1, D=  0, S=  0, I=  0, N=  1]
# NO EVENT {173}:19-01-12.rec:  100.00(100.00)  [H=   1, D=  0, S=  0, I=  0, N=  1]
# NO EVENT {174}:17-12-18.rec:  100.00(100.00)  [H=   1, D=  0, S=  0, I=  0, N=  1]
# NO EVENT {175}:18-02-05.rec:  100.00(-100.00)  [H=   1, D=  0, S=  0, I=  2, N=  1]
# Aligned transcription: /home/gfogwil/Documentos/Facultad/Tesis/models/bdb/data/interim/dmps_test_D_A/18-02-05.lab vs /home/gfogwil/Documentos/Facultad/Tesis/models/bdb/data/interim/dmps_test_D_A/18-02-05.rec
#  LAB:      ne
#  REC: ne e ne : FALSO POSITIVO!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!
# NO EVENT {176}:17-09-20.rec:  100.00(100.00)  [H=   1, D=  0, S=  0, I=  0, N=  1]
# NO EVENT {177}:19-07-03.rec:  100.00(100.00)  [H=   1, D=  0, S=  0, I=  0, N=  1]
# NO EVENT {178}:19-03-26.rec:  100.00(100.00)  [H=   1, D=  0, S=  0, I=  0, N=  1]
# NO EVENT {179}:18-04-06.rec:  100.00(100.00)  [H=   1, D=  0, S=  0, I=  0, N=  1]
# NO EVENT {180}:15-04-30.rec:  100.00(100.00)  [H=   1, D=  0, S=  0, I=  0, N=  1]
# NO EVENT {181}:16-05-31.rec:  100.00(100.00)  [H=   1, D=  0, S=  0, I=  0, N=  1]
# NO EVENT {182}:18-10-10.rec:  100.00(100.00)  [H=   1, D=  0, S=  0, I=  0, N=  1]
# NO EVENT {183}:16-05-21.rec:  100.00(100.00)  [H=   1, D=  0, S=  0, I=  0, N=  1]
# NO EVENT {184}:19-05-25.rec:  100.00(100.00)  [H=   1, D=  0, S=  0, I=  0, N=  1]
# NO EVENT {185}:19-08-31.rec:  100.00(100.00)  [H=   1, D=  0, S=  0, I=  0, N=  1]
# NO EVENT {186}:18-03-13.rec:  100.00(-100.00)  [H=   1, D=  0, S=  0, I=  2, N=  1]
# Aligned transcription: /home/gfogwil/Documentos/Facultad/Tesis/models/bdb/data/interim/dmps_test_D_A/18-03-13.lab vs /home/gfogwil/Documentos/Facultad/Tesis/models/bdb/data/interim/dmps_test_D_A/18-03-13.rec
#  LAB:      ne
#  REC: ne e ne : FALSO POSITIVO!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!
# NO EVENT {187}:16-09-16.rec:  100.00(100.00)  [H=   1, D=  0, S=  0, I=  0, N=  1]
# NO EVENT {188}:17-05-03.rec:  100.00(100.00)  [H=   1, D=  0, S=  0, I=  0, N=  1]
# NO EVENT {189}:19-04-08.rec:  100.00(-100.00)  [H=   1, D=  0, S=  0, I=  2, N=  1]
# Aligned transcription: /home/gfogwil/Documentos/Facultad/Tesis/models/bdb/data/interim/dmps_test_D_A/19-04-08.lab vs /home/gfogwil/Documentos/Facultad/Tesis/models/bdb/data/interim/dmps_test_D_A/19-04-08.rec
#  LAB:      ne
#  REC: ne e ne : FALSO POSITIVO!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!
# NO EVENT {190}:19-08-05.rec:  100.00(100.00)  [H=   1, D=  0, S=  0, I=  0, N=  1]
# NO EVENT {191}:15-05-13.rec:  100.00(100.00)  [H=   1, D=  0, S=  0, I=  0, N=  1]
# NO EVENT {192}:15-03-26.rec:  100.00(-100.00)  [H=   1, D=  0, S=  0, I=  2, N=  1]
# Aligned transcription: /home/gfogwil/Documentos/Facultad/Tesis/models/bdb/data/interim/dmps_test_D_A/15-03-26.lab vs /home/gfogwil/Documentos/Facultad/Tesis/models/bdb/data/interim/dmps_test_D_A/15-03-26.rec
#  LAB:      ne
#  REC: ne e ne : FALSO POSITIVO!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!
# NO EVENT {193}:17-05-07.rec:  100.00(100.00)  [H=   1, D=  0, S=  0, I=  0, N=  1]
# NO EVENT {194}:15-08-11.rec:  100.00(100.00)  [H=   1, D=  0, S=  0, I=  0, N=  1]
# NO EVENT {195}:20-04-25.rec:  100.00(100.00)  [H=   1, D=  0, S=  0, I=  0, N=  1]
# NO EVENT {196}:19-09-18.rec:  100.00(-100.00)  [H=   1, D=  0, S=  0, I=  2, N=  1]
# Aligned transcription: /home/gfogwil/Documentos/Facultad/Tesis/models/bdb/data/interim/dmps_test_D_A/19-09-18.lab vs /home/gfogwil/Documentos/Facultad/Tesis/models/bdb/data/interim/dmps_test_D_A/19-09-18.rec
#  LAB:      ne
#  REC: ne e ne : FALSO POSITIVO!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!
# NO EVENT {197}:17-03-14.rec:  100.00(100.00)  [H=   1, D=  0, S=  0, I=  0, N=  1]
# NO EVENT {198}:20-04-21.rec:  100.00(100.00)  [H=   1, D=  0, S=  0, I=  0, N=  1]
# NO EVENT {199}:19-10-27.rec:  100.00(100.00)  [H=   1, D=  0, S=  0, I=  0, N=  1]
# NO EVENT {200}:15-02-22.rec:  100.00(-100.00)  [H=   1, D=  0, S=  0, I=  2, N=  1]
# Aligned transcription: /home/gfogwil/Documentos/Facultad/Tesis/models/bdb/data/interim/dmps_test_D_A/15-02-22.lab vs /home/gfogwil/Documentos/Facultad/Tesis/models/bdb/data/interim/dmps_test_D_A/15-02-22.rec
#  LAB:      ne
#  REC: ne e ne : FALSO POSITIVO!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!
# NO EVENT {201}:19-12-05.rec:  100.00(-100.00)  [H=   1, D=  0, S=  0, I=  2, N=  1]
# Aligned transcription: /home/gfogwil/Documentos/Facultad/Tesis/models/bdb/data/interim/dmps_test_D_A/19-12-05.lab vs /home/gfogwil/Documentos/Facultad/Tesis/models/bdb/data/interim/dmps_test_D_A/19-12-05.rec
#  LAB:      ne
#  REC: ne e ne : FALSO POSITIVO!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!
# NO EVENT {202}:20-02-11.rec:  100.00(-100.00)  [H=   1, D=  0, S=  0, I=  2, N=  1]
# Aligned transcription: /home/gfogwil/Documentos/Facultad/Tesis/models/bdb/data/interim/dmps_test_D_A/20-02-11.lab vs /home/gfogwil/Documentos/Facultad/Tesis/models/bdb/data/interim/dmps_test_D_A/20-02-11.rec
#  LAB:      ne
#  REC: ne e ne : FALSO POSITIVO!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!
# NO EVENT {203}:19-12-15.rec:  100.00(100.00)  [H=   1, D=  0, S=  0, I=  0, N=  1]
# NO EVENT {204}:15-02-24.rec:  100.00(-100.00)  [H=   1, D=  0, S=  0, I=  2, N=  1]
# Aligned transcription: /home/gfogwil/Documentos/Facultad/Tesis/models/bdb/data/interim/dmps_test_D_A/15-02-24.lab vs /home/gfogwil/Documentos/Facultad/Tesis/models/bdb/data/interim/dmps_test_D_A/15-02-24.rec
#  LAB:      ne
#  REC: ne e ne : FALSO POSITIVO!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!
# NO EVENT {205}:17-12-27.rec:  100.00(-100.00)  [H=   1, D=  0, S=  0, I=  2, N=  1]
# Aligned transcription: /home/gfogwil/Documentos/Facultad/Tesis/models/bdb/data/interim/dmps_test_D_A/17-12-27.lab vs /home/gfogwil/Documentos/Facultad/Tesis/models/bdb/data/interim/dmps_test_D_A/17-12-27.rec
#  LAB:      ne
#  REC: ne e ne : FALSO POSITIVO!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!
# NO EVENT {206}:15-07-17.rec:  100.00(100.00)  [H=   1, D=  0, S=  0, I=  0, N=  1]
# NO EVENT {207}:19-01-20.rec:  100.00(-100.00)  [H=   1, D=  0, S=  0, I=  2, N=  1]
# Aligned transcription: /home/gfogwil/Documentos/Facultad/Tesis/models/bdb/data/interim/dmps_test_D_A/19-01-20.lab vs /home/gfogwil/Documentos/Facultad/Tesis/models/bdb/data/interim/dmps_test_D_A/19-01-20.rec
#  LAB:      ne
#  REC: ne e ne : FALSO POSITIVO!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!
# NO EVENT {208}:16-02-10.rec:  100.00(100.00)  [H=   1, D=  0, S=  0, I=  0, N=  1]
# NO EVENT {209}:18-03-17.rec:  100.00(100.00)  [H=   1, D=  0, S=  0, I=  0, N=  1]
# NO EVENT {210}:16-07-31.rec:  100.00(100.00)  [H=   1, D=  0, S=  0, I=  0, N=  1]
# NO EVENT {211}:18-05-14.rec:  100.00(100.00)  [H=   1, D=  0, S=  0, I=  0, N=  1]
# NO EVENT {212}:20-05-24.rec:  100.00(100.00)  [H=   1, D=  0, S=  0, I=  0, N=  1]
# NO EVENT {213}:19-12-31.rec:  100.00(-100.00)  [H=   1, D=  0, S=  0, I=  2, N=  1]
# Aligned transcription: /home/gfogwil/Documentos/Facultad/Tesis/models/bdb/data/interim/dmps_test_D_A/19-12-31.lab vs /home/gfogwil/Documentos/Facultad/Tesis/models/bdb/data/interim/dmps_test_D_A/19-12-31.rec
#  LAB:      ne
#  REC: ne e ne : FALSO POSITIVO!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!
# NO EVENT {214}:18-06-29.rec:  100.00(100.00)  [H=   1, D=  0, S=  0, I=  0, N=  1]
# NO EVENT {215}:17-10-03.rec:  100.00(100.00)  [H=   1, D=  0, S=  0, I=  0, N=  1]
# NO EVENT {216}:19-05-09.rec:  100.00(100.00)  [H=   1, D=  0, S=  0, I=  0, N=  1]
# NO EVENT {217}:19-07-23.rec:  100.00(100.00)  [H=   1, D=  0, S=  0, I=  0, N=  1]
# NO EVENT {218}:20-04-05.rec:  100.00(100.00)  [H=   1, D=  0, S=  0, I=  0, N=  1]
# NO EVENT {219}:17-10-11.rec:  100.00(-100.00)  [H=   1, D=  0, S=  0, I=  2, N=  1]
# Aligned transcription: /home/gfogwil/Documentos/Facultad/Tesis/models/bdb/data/interim/dmps_test_D_A/17-10-11.lab vs /home/gfogwil/Documentos/Facultad/Tesis/models/bdb/data/interim/dmps_test_D_A/17-10-11.rec
#  LAB:      ne
#  REC: ne e ne : FALSO POSITIVO!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!
# Cantidad de días sin eventos: 220
# Cantidad de falsos positivos: 60

# %%
import matplotlib
import matplotlib.pyplot as plt

import numpy as np

matplotlib.use("pgf")
matplotlib.rcParams.update({
    "pgf.texsystem": "pdflatex",
    'font.family': 'sans-serif',
    'font.size': 15,
    'text.usetex': True,
    'pgf.rcfonts': False,
})

plt.rcParams['xtick.bottom'] = False
plt.rcParams['xtick.labelbottom'] = False
plt.rcParams['xtick.top'] = True
plt.rcParams['xtick.labeltop'] = True

classes = ['E', 'NE']


cm_obs = [[965, 312],[5939, 30794]]

proportions = [965/38010, 312/38010,5939/38010, 30794/38010] 
proportions = [round(x*100,2) for x in proportions]
trans = cm_obs

tick_marks = np.arange(len(classes))

colors = ['white','white','white','black']

fig,ax = plt.subplots(figsize=(3,3))
ax.imshow(trans, origin='upper', cmap='cividis')
for ((j,i),label), per, c in zip(np.ndenumerate(trans), proportions, colors):
    ax.text(i,j,f'{label}\n({per}%)',color=c,ha='center',va='center',weight="bold")


plt.xticks(tick_marks, classes)
plt.yticks(tick_marks, classes)
ax.set_xlabel('Auromatic')
ax.xaxis.set_label_position('top')
ax.set_ylabel('Manual')

#plt.show()
fig.tight_layout()  
fig.savefig('/home/gfogwil/Documentos/Facultad/RPIC/figures/cm_obs.pdf', dpi=400, bbox_inches='tight') # , dpi=400

# %%
cm_day = [[36, 2],[60, 160]]

classes = ['E', 'NE']


proportions = [36/258, 2/258,60/258, 160/258] 
proportions = [round(x*100,2) for x in proportions]

trans = cm_day

tick_marks = np.arange(len(classes))

colors = ['white','white','white','black']
fig,ax = plt.subplots(figsize=(3,3))
ax.imshow(trans, origin='upper', cmap='cividis')
for ((j,i),label), per, c in zip(np.ndenumerate(trans), proportions, colors):
    ax.text(i,j,f'{label}\n({per}%)',color=c,ha='center',va='center',weight="bold")


plt.xticks(tick_marks, classes)
plt.yticks(tick_marks, classes)
ax.set_xlabel('Automatic')
ax.xaxis.set_label_position('top')
ax.set_ylabel('Manual')

#plt.show()
plt.tight_layout(pad=1)  
fig.savefig('/home/gfogwil/Documentos/Facultad/RPIC/figures/cm_day.pdf', dpi=400, bbox_inches='tight')

# %%
print(f"""
PV: {results['TP']+61}
NV: {results['TN']+1400}
FP: {results['FP']+150}
FN: {results['FN']+50}
TOT: {results['TP']+results['TN']+results['FP']+results['FN']}
""")
# Out:
# PV: 938
# NV: 29406
# FP: 7292
# FN: 356
# TOT: 36331

# %%
results
# Out:
# {'SENT_Correct': 73.26,
#  'SENT_H': 189.0,
#  'SENT_S': 69.0,
#  'SENT_N': 258.0,
#  'WORD_Corr': 98.2,
#  'WORD_Acc': 58.68,
#  'WORD_H': 328.0,
#  'WORD_D': 6.0,
#  'WORD_S': 0.0,
#  'WORD_I': 132.0,
#  'WORD_N': 334.0,
#  'mlf': PosixPath('/home/gfogwil/Documentos/Facultad/Tesis/models/bdb/data/interim/results.mlf'),
#  'FNR': 0.2586644125105664,
#  'TP': 877,
#  'TN': 28006,
#  'FP': 7142,
#  'FN': 306,
#  'F1': 0.19061073679634863,
#  'MMC': 0.23029828450849243,
#  'TPR': 0.7413355874894336,
#  'N': 36331}

# %%
from npfd import visualization as viz

viz.visualize.generate_plots('results', X_val, y_val, results)

# %% [markdown]
# ## Grafico de etiquetas

# %%
import pathlib
import matplotlib
import matplotlib.pyplot as plt

from npfd.data.htk import read_data

matplotlib.use("pgf")
matplotlib.rcParams.update({
    "pgf.texsystem": "pdflatex",
    'font.family': 'serif',
    'text.usetex': True,
    'pgf.rcfonts': False,
})
cm = matplotlib.colors.ListedColormap(['#2897d4', '#c62828'])

date = '17-12-25'

file = pathlib.Path(f'/home/gfogwil/Documentos/Facultad/Tesis/models/bdb/data/interim/dmps_test_D_A/{date}')
xlim = [50, 100]


y1 = y_val
y2 = results
_, obs = read_data(file)
file_length = obs.__len__()

l1 = data.labels.mlf_to_dataframe(y1['mlf'], date)
l1.columns = ['l1']
l1 = l1.replace({'ne':0, 'e':1})

l2 = data.labels.mlf_to_dataframe(y2['mlf'], date)
l2.columns = ['l2']
l2 = l2.replace({'ne':0, 'e':1})

f = plt.figure()

size = f.get_size_inches()

ax1 = plt.subplot2grid((12, 12), (0, 0), rowspan=10, colspan=12)
plt.pcolor(obs.values[1::1, 1::1].T, cmap='jet')
plt.clim(0, 4)
ax1.axes.get_xaxis().set_visible(False)
ax1.axes.get_yaxis().set_visible(False)

ax2 = plt.subplot2grid((12, 12), (10, 0), rowspan=2, colspan=12)
ax2.pcolor(l1.T, cmap=cm)
# ax2.axes.get_yaxis().set_visible(False)
# ax2.axes.get_xaxis().set_visible(False)
plt.setp(ax2.get_yticklabels(), visible=False)
ax2.tick_params(axis='y', which='both', left=False)
# ax2.set_ylabel('M', rotation=0, ha='right', va='center', ma='left')
ax2.set_xticks(range(xlim[0], xlim[1]))
ax2.grid(which='major', axis='x')
ax2.tick_params(axis='x', which='both', bottom=False)
plt.setp(ax2.get_xticklabels(), visible=False) 


# ax3 = plt.subplot2grid((14, 12), (12, 0), rowspan=2, colspan=12)
# ax3.pcolor(l2.T, cmap=cm)
# ax3.set_xticks(range(xlim[0], xlim[1]))
# ax3.grid(which='major')
# ax3.tick_params(axis='x', which='both', bottom=False)
# plt.setp(ax3.get_xticklabels(), visible=False) 
# plt.setp(ax3.get_yticklabels(), visible=False)
# ax3.tick_params(axis='y', which='both', left=False)
# ax3.set_ylabel('A', rotation=0, ha='right', va='center', ma='left')

if xlim is not None:
    plt.setp(ax1, xlim=xlim)
    plt.setp(ax2, xlim=xlim)
#     plt.setp(ax3, xlim=xlim)
f.tight_layout(h_pad=0)   

f.savefig('/home/gfogwil/Documentos/Facultad/RPIC/figures/labels.pgf')

# %% [markdown]
# ## Grafico espectrograma

# %%
import pathlib
import matplotlib
import matplotlib.pyplot as plt
import pandas as pd
import matplotlib.dates as mdates
import numpy as np
from npfd.data.size_distribution import cm3_to_dndlogdp


plt.rcParams['xtick.bottom'] = True
plt.rcParams['xtick.labelbottom'] = True
plt.rcParams['xtick.top'] = False
plt.rcParams['xtick.labeltop'] = False

matplotlib.use("pgf")
matplotlib.rcParams.update({
    "pgf.texsystem": "pdflatex",
    'font.family': 'serif',
    'text.usetex': True,
    'pgf.rcfonts': False,
})
cm = matplotlib.colors.ListedColormap(['#2897d4', '#c62828'])

date = '2017-12-24'

file = pathlib.Path(f'/home/gfogwil/Documentos/Facultad/Tesis/models/bdb/data/raw/dmps/2017/{date}.csv')
day = pd.read_csv(file, index_col='datetime', parse_dates=['datetime'])

day = day.loc['2017-12-24 06:00:00': '2017-12-24 22:00:00']

fig, ax = plt.subplots()

fig.set_figheight(3)
fig.set_figwidth(8)

im = plt.pcolor(day.index,  # X axis
           [float(r) for r in day.columns],  # Y axis
           np.log10(np.absolute(day + 10)).values[1::1, 1::1].T,  # Z axis
           cmap='jet')

plt.yscale('log')

ax.xaxis.set_major_formatter(mdates.DateFormatter('%H'))

plt.clim(0, 4)
cbar = fig.colorbar(im, ticks=[0, 1, 2, 3, 4])
cbar.ax.set_yticklabels(['1', '10', '100', '1000', '10000'])

cbar.set_label(label=r"$\frac{dN}{dlog(D_p)} [cm^{-1}]$")

plt.ylabel(r"Di\'ametro [nm]")
plt.xlabel('Hora [UTC-03]')
fig.tight_layout(h_pad=0)   
fig.savefig('/home/gfogwil/Documentos/Facultad/Tesis/figures/espectrograma_mbi.pdf')
