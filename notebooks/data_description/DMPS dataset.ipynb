# %%
# %reload_ext autoreload
# %autoreload 2

# %%
from npfd import data

# Make datasets
X_train, X_val, y_train, y_val = data.dataset.make_dataset('db3', clean_interim_dir=True)
# Out:
# INFO:root:Converting real raw files to HTK format ...
# INFO:root:Generating Master Label File (Train)...
# INFO:root:Generating Master Label File (Test)...

# %%
from npfd import visualization as viz
import pathlib

viz.visualize.generate_plots('/home/gfogwil/temp', X_train, y_train)

# with open(X_train['script_file']) as fi:
#     for file in fi:
# #         file = pathlib.Path(file)
#         print(file)
#         viz.visualize.plot_X_y1(pathlib.Path(file.strip()), y_train, '/home/gfogwil/temp')
